# %%
import numpy as np
import SearchSpace as ss
import ModelBuild as Builder
import TrainModel as Trainer
from google.colab import drive
import pandas as pd
import os
import torch
import random

import torch
from torch.utils.data import DataLoader, Subset
from torchvision import datasets, transforms

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
random_params = ss.create_param_combinations(strategy="genetic")
print("random Search Combinations:", random_params)
# Out:
# random Search Combinations: [{'num_layers': 4, 'units_per_layer': 34, 'activation': 'sigmoid', 'learning_rate': 0.0012288466899514675, 'batch_size': 32, 'dropout_rate': 0.37415798952077933, 'l2_reg_strength': 3.253866542962493e-05}]

# %%
#
# 初始化种群
def initialize_population(size=50):
    population = []
    for _ in range(size):
        individual = ss.create_param_combinations(strategy="genetic")
        population.append(individual[0])
    return population

# 选择多个父代个体（精英选择+轮盘赌）
def selection(population, fitness_scores, num_parents=10):
    # 保留适应度最高的个体（精英选择）
    selected_indices = sorted(range(len(fitness_scores)), key=lambda i: fitness_scores[i])[:num_parents]
    selected_population = [population[i] for i in selected_indices]

    # 根据适应度选择其他父代（轮盘赌选择）
    total_fitness = sum(fitness_scores)
    selection_probs = [1 - (f / total_fitness) for f in fitness_scores]
    selected_population += random.choices(population, weights=selection_probs, k=num_parents)

    return selected_population

# 交叉操作生成新个体
def crossover(parent1, parent2):
    child = {}
    for key in parent1.keys():
        child[key] = random.choice([parent1[key], parent2[key]])
    return child

# 变异操作
def mutation(individual, search_space, mutation_rate=0.1):
    # 遍历个体的所有参数并随机变异
    for param, config in search_space.items():
        if random.random() < mutation_rate:  # 以一定概率进行变异
            if "values" in config:  # 离散的选择
                individual[param] = np.random.choice(config["values"])
            elif config["type"] == "continuous":  # 连续范围的选择
                if config.get("scale") == "log":
                    # Log-scale变异：在log范围内随机选择
                    individual[param] = np.exp(np.random.uniform(np.log(config["min"]), np.log(config["max"])))
                else:
                    # Linear-scale变异：在min和max之间随机选择
                    individual[param] = np.random.uniform(config["min"], config["max"])

                # 确保整数型参数（如 units_per_layer）变异后依然为整数
                if param == "units_per_layer":
                    individual[param] = int(individual[param])

    return individual

# %%
# 遗传算法搜索函数
def genetic_search(train_set, val_set, epochs=10, save_dir="/content/drive/MyDrive/DL_HPO/GeneticResult"):
    search_space = ss.get_search_space("genetic")
    population_size = 50
    generations = 20
    mutation_rate = 0.1
    num_parents = 10  # 每代保留的父代数量

    all_results = []
    best_result = None
    best_val_acc = 0.0
    best_model_wts = None
    total_training_time = 0  # 初始化总训练时间

    # 确保保存路径存在
    os.makedirs(save_dir, exist_ok=True)

    # 检查是否已经存在汇总文件，如果存在，直接加载以继续
    summary_file_path = f"{save_dir}/genetic_result.csv"
    if os.path.exists(summary_file_path):
        existing_results_df = pd.read_csv(summary_file_path)
        total_training_time = existing_results_df["total_training_time"].max()  # 获取已保存的总时间

    # 初始化种群
    population = initialize_population(population_size)

    for generation in range(generations):
        print(f"Generation {generation + 1}/{generations}")

        # 评估当前种群的适应度
        fitness_scores = []
        for param_index, params in enumerate(population):
            print(params)
            # 构建模型并加载数据
            model = Builder.build_model(params)
            batch_size = int(params["batch_size"])
            train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
            val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

            # 训练模型
            result = Trainer.train_model(model, train_loader, val_loader, epochs=epochs)
            fitness_scores.append(result["val_losses"][-1])  # 使用验证损失作为适应度

            # 累加当前模型的训练时间
            total_training_time += result["training_time"]

            # 记录结果
            result_summary = {
                "generation": generation,
                "param_index": param_index,
                "params": params,
                "strategy": "genetic",
                "train_loss": result["train_losses"][-1],
                "val_loss": result["val_losses"][-1],
                "train_accuracy": result["train_accuracies"][-1],
                "val_accuracy": result["val_accuracies"][-1],
                "training_time": result["training_time"],
                "total_training_time": total_training_time
            }
            all_results.append(result_summary)

            # 追加当前结果到汇总文件
            result_df = pd.DataFrame([result_summary])
            if os.path.exists(summary_file_path):
                result_df.to_csv(summary_file_path, mode='a', header=False, index=False)
            else:
                result_df.to_csv(summary_file_path, mode='w', index=False)

            # 更新最佳模型并保存
            if result["val_accuracies"][-1] > best_val_acc:
                best_val_acc = result["val_accuracies"][-1]
                best_result = result_summary
                best_model_wts = model.state_dict()

                # 保存最佳结果到 Google Drive
                best_result_df = pd.DataFrame([best_result])
                best_result_df.to_csv(f"{save_dir}/best_genetic_result.csv", index=False)
                torch.save(best_model_wts, f"{save_dir}/best_model_weights.pt")

        # 基于适应度选择父代并生成新一代
        selected_parents = selection(population, fitness_scores, num_parents)
        new_population = []

        while len(new_population) < population_size:
            parent1, parent2 = random.sample(selected_parents, 2)
            child = crossover(parent1, parent2)
            child = mutation(child, search_space,mutation_rate)
            new_population.append(child)

        # 更新种群
        population = new_population

    return all_results, best_result, best_model_wts

# %%
# 下载并预处理 MNIST 数据集
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# 加载 MNIST 数据集
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# 截取 1000 个训练样本和 100 个验证样本
train_subset = Subset(train_dataset, range(3000))
val_subset = Subset(test_dataset, range(500))

# %%
all_results, best_result, best_model_wts = genetic_search(train_subset, val_subset, epochs=10,save_dir="/content/drive/MyDrive/DL_HPO/GeneticResult")
# Out:
# Generation 1/20
# {'num_layers': 2, 'units_per_layer': 70, 'activation': 'sigmoid', 'learning_rate': 0.0006154567295061833, 'batch_size': 64, 'dropout_rate': 0.2456922394788097, 'l2_reg_strength': 4.83732955789123e-07}
# {'num_layers': 4, 'units_per_layer': 16, 'activation': 'tanh', 'learning_rate': 0.01984254734044944, 'batch_size': 256, 'dropout_rate': 0.26957003708751615, 'l2_reg_strength': 1.1565571735797797e-06}
# {'num_layers': 4, 'units_per_layer': 111, 'activation': 'relu', 'learning_rate': 0.1464281537511819, 'batch_size': 128, 'dropout_rate': 0.551353021391362, 'l2_reg_strength': 4.100657697589167e-07}
# {'num_layers': 4, 'units_per_layer': 32, 'activation': 'tanh', 'learning_rate': 0.009360891820260555, 'batch_size': 256, 'dropout_rate': 0.3296643958205882, 'l2_reg_strength': 0.00014526174930766284}
# {'num_layers': 3, 'units_per_layer': 51, 'activation': 'tanh', 'learning_rate': 0.22862965523679232, 'batch_size': 64, 'dropout_rate': 0.5435152460381255, 'l2_reg_strength': 2.108995251398081e-06}
# {'num_layers': 3, 'units_per_layer': 127, 'activation': 'sigmoid', 'learning_rate': 0.030287733199612994, 'batch_size': 64, 'dropout_rate': 0.08702653258276075, 'l2_reg_strength': 0.0016251702828632328}
# {'num_layers': 1, 'units_per_layer': 49, 'activation': 'sigmoid', 'learning_rate': 0.05621951943576119, 'batch_size': 16, 'dropout_rate': 0.5863055579640332, 'l2_reg_strength': 2.853105103680663e-07}
# {'num_layers': 1, 'units_per_layer': 114, 'activation': 'sigmoid', 'learning_rate': 0.0004784191205210125, 'batch_size': 128, 'dropout_rate': 0.43650390494652536, 'l2_reg_strength': 0.0002361248831616582}
# {'num_layers': 1, 'units_per_layer': 49, 'activation': 'sigmoid', 'learning_rate': 0.00016218916168286905, 'batch_size': 128, 'dropout_rate': 0.3352515808136365, 'l2_reg_strength': 0.009027894443904972}
# {'num_layers': 3, 'units_per_layer': 73, 'activation': 'tanh', 'learning_rate': 0.2756674786230519, 'batch_size': 256, 'dropout_rate': 0.4288971475502837, 'l2_reg_strength': 0.0007342569532333862}
# {'num_layers': 4, 'units_per_layer': 77, 'activation': 'sigmoid', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 1, 'units_per_layer': 8, 'activation': 'sigmoid', 'learning_rate': 0.008623102344017794, 'batch_size': 256, 'dropout_rate': 0.5958131692899232, 'l2_reg_strength': 0.008442460202847972}
# {'num_layers': 4, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.16938519422436923, 'batch_size': 256, 'dropout_rate': 0.34154335654021445, 'l2_reg_strength': 4.820125144701928e-05}
# {'num_layers': 3, 'units_per_layer': 3, 'activation': 'relu', 'learning_rate': 0.020658873702778028, 'batch_size': 64, 'dropout_rate': 0.5460533132703352, 'l2_reg_strength': 0.0005207531965314319}
# {'num_layers': 2, 'units_per_layer': 115, 'activation': 'sigmoid', 'learning_rate': 0.23375765560236703, 'batch_size': 64, 'dropout_rate': 0.3053002200437044, 'l2_reg_strength': 2.8696605227620814e-06}
# {'num_layers': 1, 'units_per_layer': 62, 'activation': 'relu', 'learning_rate': 0.0012638823992888082, 'batch_size': 128, 'dropout_rate': 0.5316026998082757, 'l2_reg_strength': 6.777195950763755e-06}
# {'num_layers': 1, 'units_per_layer': 60, 'activation': 'relu', 'learning_rate': 0.013047691392008105, 'batch_size': 16, 'dropout_rate': 0.4171656195950002, 'l2_reg_strength': 0.006359135836320077}
# {'num_layers': 1, 'units_per_layer': 7, 'activation': 'tanh', 'learning_rate': 0.00011528107445745462, 'batch_size': 32, 'dropout_rate': 0.08193515948614752, 'l2_reg_strength': 8.939150646513982e-05}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.0005100458923968072, 'batch_size': 64, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 9, 'activation': 'relu', 'learning_rate': 0.001140410883668573, 'batch_size': 32, 'dropout_rate': 0.1265562972997852, 'l2_reg_strength': 0.0009056445790574233}
# {'num_layers': 2, 'units_per_layer': 43, 'activation': 'sigmoid', 'learning_rate': 0.0002590837124299213, 'batch_size': 64, 'dropout_rate': 0.11787014892439947, 'l2_reg_strength': 2.0530453381421804e-07}
# {'num_layers': 2, 'units_per_layer': 89, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size':
# {'num_layers': 3, 'units_per_layer': 33, 'activation': 'sigmoid', 'learning_rate': 0.005034849871574049, 'batch_size': 128, 'dropout_rate': 0.20253312428701148, 'l2_reg_strength': 2.086977130627799e-06}
# {'num_layers': 2, 'units_per_layer': 44, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 16, 'dropout_rate': 0.4976571641621071, 'l2_reg_strength': 1.4231540998746414e-06}
# {'num_layers': 1, 'units_per_layer': 95, 'activation': 'sigmoid', 'learning_rate': 0.008812498756217965, 'batch_size': 256, 'dropout_rate': 0.08840009707840814, 'l2_reg_strength': 1.534949508542469e-07}
# {'num_layers': 1, 'units_per_layer': 63, 'activation': 'relu', 'learning_rate': 0.06556828572291352, 'batch_size': 128, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'tanh', 'learning_rate': 0.19345078839267577, 'batch_size': 16, 'dropout_rate': 0.3404428167652954, 'l2_reg_strength': 8.466133086862695e-05}
# {'num_layers': 2, 'units_per_layer': 31, 'activation': 'sigmoid', 'learning_rate': 0.02622648775091249, 'batch_size': 16, 'dropout_rate': 0.4217598177684486, 'l2_reg_strength': 4.0191356670039015e-06}
# {'num_layers': 1, 'units_per_layer': 107, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 32, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.1136252998671323e-07}
# {'num_layers': 2, 'units_per_layer': 41, 'activation': 'tanh', 'learning_rate': 0.22837734152296257, 'batch_size': 16, 'dropout_rate': 0.5624672256040298, 'l2_reg_strength': 0.0015560664090692406}
# {'num_layers': 1, 'units_per_layer': 22, 'activation': 'sigmoid', 'learning_rate': 0.0002570256059211036, 'batch_size': 256, 'dropout_rate': 0.5354132811689291, 'l2_reg_strength': 1.1394900954993436e-05}
# {'num_layers': 1, 'units_per_layer': 45, 'activation': 'sigmoid', 'learning_rate': 0.0029709662108413355, 'batch_size': 256, 'dropout_rate': 0.12051873149644289, 'l2_reg_strength': 0.0005409149227505495}
# {'num_layers': 2, 'units_per_layer': 26, 'activation': 'relu', 'learning_rate': 0.0004646686752390975, 'batch_size': 16, 'dropout_rate': 0.28556067504198446, 'l2_reg_strength': 9.795887565116812e-07}
# {'num_layers': 4, 'units_per_layer': 61, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 0.001199658632517135}
# Generation 2/20
# {'num_layers': 1, 'units_per_layer': 26, 'activation': 'relu', 'learning_rate': 0.06556828572291352, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 9.795887565116812e-07}
# {'num_layers': 3, 'units_per_layer': 33, 'activation': 'sigmoid', 'learning_rate': 0.005034849871574049, 'batch_size': 256, 'dropout_rate': 0.20253312428701148, 'l2_reg_strength': 2.61857134845459e-07}
# {'num_layers': 1, 'units_per_layer': 60, 'activation': 'tanh', 'learning_rate': 0.0005100458923968072, 'batch_size': 128, 'dropout_rate': 0.32898109660541475, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 2, 'units_per_layer': 89, 'activation': 'tanh', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.07184863938560809, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength':
 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 2, 'units_per_layer': 26, 'activation': 'sigmoid', 'learning_rate': 0.0002590837124299213, 'batch_size': 16, 'dropout_rate': 0.11787014892439947, 'l2_reg_strength': 2.0530453381421804e-07}
# {'num_layers': 4, 'units_per_layer': 77, 'activation': 'relu', 'learning_rate': 0.013047691392008105, 'batch_size': 16, 'dropout_rate': 0.4171656195950002, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 1, 'units_per_layer': 60, 'activation': 'relu', 'learning_rate': 0.16938519422436923, 'batch_size': 16, 'dropout_rate': 0.4171656195950002, 'l2_reg_strength': 4.820125144701928e-05}
# {'num_layers': 1, 'units_per_layer': 33, 'activation': 'sigmoid', 'learning_rate': 0.002617914416136642, 'batch_size': 16, 'dropout_rate': 0.20253312428701148, 'l2_reg_strength': 0.006359135836320077}
# Generation 3/20
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 0.009736409518911408}
# {'num_layers': 2, 'units_per_layer': 89, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 128, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 7.866819023093336e-06}
# {'num_layers': 1, 'units_per_layer': 57, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 3, 'units_per_layer': 61, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 64, 'dropout_rate': 0.2028915041495527, 'l2_reg_strength': 0.001199658632517135}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 4, 'units_per_layer': 67, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.4486758926120103, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 64, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 1, 'units_per_layer': 59, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 16, 'dropout_rate': 0.26886834765384965, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 3, 'units_per_layer': 61, 'activation': 'tanh', 'learning_rate': 0.03655388443219044, 'batch_size': 16, 'dropout_rate': 0.4486758926120103, 'l2_reg_strength': 1.4231540998746414e-06}
# {'num_layers': 3, 'units_per_layer': 85, 'activation': 'tanh', 'learning_rate': 0.0005100458923968072, 'batch_size': 256, 'dropout_rate': 0.13773555856576136, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 4, 'units_per_layer': 62, 'activation': 'tanh', 'learning_rate': 0.00014690406314212288, 'batch_size': 32, 'dropout_rate': 0.052389914699087166, 'l2_reg_strength': 4.533581873465902e-06}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 62, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.4775693627805365, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.10470518995694936, 'batch_size': 16, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 16, 'dropout_rate': 0.2028915041495527, 'l2_reg_strength': 0.001199658632517135}
# {'num_layers': 1, 'units_per_layer': 62, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.052389914699087166, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.21144287336434694, 'batch_size': 64, 'dropout_rate': 0.4486758926120103, 'l2_reg_strength': 4.533581873465902e-06}
# {'num_layers': 3, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 256, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 0.009736409518911408}
# {'num_layers': 3, 'units_per_layer': 89, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 128, 'dropout_rate': 0.2028915041495527, 'l2_reg_strength': 6.497986229936596e-06}
# {'num_layers': 1, 'units_per_layer': 51, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 1, 'units_per_layer': 89, 'activation': 'tanh', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 3, 'units_per_layer': 60, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.12581083925531744, 'l2_reg_strength': 0.006359135836320077}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.30530788291065286, 'l2_reg_strength': 0.0025279375077931804}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.5254381553224694, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.0005100458923968072, 'batch_size': 64, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 0.001199658632517135}
# {'num_layers': 3, 'units_per_layer': 60, 'activation': 'relu', 'learning_rate': 0.013047691392008105, 'batch_size': 16, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 61, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.4486758926120103, 'l2_reg_strength': 4.533581873465902e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'sigmoid', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 67, 'activation': 'tanh', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 4.533581873465902e-06}
# {'num_layers': 1, 'units_per_layer': 6, 'activation': 'relu', 'learning_rate': 0.0005100458923968072, 'batch_size': 16, 'dropout_rate': 0.13773555856576136, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 3, 'units_per_layer': 67, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 256, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 4, 'units_per_layer': 62, 'activation': 'tanh', 'learning_rate': 0.21144287336434694, 'batch_size': 32, 'dropout_rate': 0.4486758926120103, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.01053060845122253, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 60, 'activation': 'relu', 'learning_rate': 0.00014690406314212288, 'batch_size': 16, 'dropout_rate': 0.052389914699087166, 'l2_reg_strength': 0.006359135836320077}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 4, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 128, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 1, 'units_per_layer': 121, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.23760390916862928, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 3, 'units_per_layer': 124, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 4.533581873465902e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'sigmoid', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.5868282206524954, 'l2_reg_strength': 2.8199452691426515e-06}
# Generation 4/20
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0010131195234575141, 'batch_size': 64, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 0.001199658632517135}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 21, 'activation': 'tanh', 'learning_rate': 0.0005100458923968072, 'batch_size': 256, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 64, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.000268251632014817, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 9, 'activation': 'tanh', 'learning_rate': 0.00021504402765258116, 'batch_size': 256, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 3.364678680611867e-05}
# {'num_layers': 3, 'units_per_layer': 85, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 1, 'units_per_layer': 124, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 3, 'units_per_layer': 48, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.12581083925531744, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 124, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.18869131284644453, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.01681189943341364, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 2.0086545991792488e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.547231981033693, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'sigmoid', 'learning_rate': 0.06961190873475162, 'batch_size': 32, 'dropout_rate': 0.5959396497944482, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 37, 'activation': 'tanh', 'learning_rate': 0.01088838200974474, 'batch_size': 16, 'dropout_rate': 0.12581083925531744, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'sigmoid', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 4, 'units_per_layer': 113, 'activation': 'tanh', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 1.3801248881117488e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0005486723211159336, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.5254381553224694, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 32, 'dropout_rate': 0.4034068835302451, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.2028915041495527, 'l2_reg_strength': 0.001199658632517135}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 3, 'units_per_layer': 105, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.00018454727773415953, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 0.006359135836320077}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.5122796972250627, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 67, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 128, 'dropout_rate': 0.5458394891170806, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.05958094182107811, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 1.5820946194700673e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 16, 'dropout_rate': 0.2028915041495527, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 0.00015760249083574478}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.0008574413631530993, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 95, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 0.008592602120307768}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.0029063064807709144}
# {'num_layers': 4, 'units_per_layer': 67, 'activation': 'relu', 'learning_rate': 0.00010755173241395858, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 0.007470107366260217}
# Generation 5/20
# {'num_layers': 3, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 256, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.5178343979321242e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.547231981033693, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.03655388443219044, 'batch_size': 16, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.024989962549360735, 'batch_size': 32, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.06220454757900903, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 256, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 4, 'units_per_layer': 95, 'activation': 'sigmoid', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.5820946194700673e-07}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'tanh', 'learning_rate': 0.0005486723211159336, 'batch_size': 32, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 105, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 3, 'units_per_layer': 79, 'activation': 'sigmoid', 'learning_rate': 0.06961190873475162, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.0029063064807709144}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 1, 'units_per_layer': 124, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 95, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 16, 'dropout_rate': 0.3133863301859677, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.10522212934609224, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.29704982339778296, 'l2_reg_strength': 0.0006785300949670753}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 64, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'sigmoid', 'learning_rate': 0.06961190873475162, 'batch_size': 32, 'dropout_rate': 0.547231981033693, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0007805777582664057, 'batch_size': 64, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.06961190873475162, 'batch_size': 64, 'dropout_rate': 0.4553291887581486, 'l2_reg_strength': 0.00015760249083574478}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.01088838200974474, 'batch_size': 16, 'dropout_rate': 0.12581083925531744, 'l2_reg_strength': 0.0029063064807709144}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.03655388443219044, 'batch_size': 32, 'dropout_rate': 0.547231981033693, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00011527012377560253, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.0029063064807709144}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.07388319809754636, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 3, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.00023374250693212716, 'batch_size': 32, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 1.9712405242809197e-06}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.21144287336434694, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0005486723211159336, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0065322243136635e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.21144287336434694, 'batch_size': 16, 'dropout_rate': 0.1638809461909557, 'l2_reg_strength': 0.0029063064807709144}
# {'num_layers': 1, 'units_per_layer': 79, 'activation': 'tanh', 'learning_rate': 0.06961190873475162, 'batch_size': 16, 'dropout_rate': 0.26284671836493045, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 1, 'units_per_layer': 124, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.18622172449690755, 'l2_reg_strength': 2.8199452691426515e-06}
# {'num_layers': 2, 'units_per_layer': 78, 'activation': 'relu', 'learning_rate': 0.03655388443219044, 'batch_size': 256, 'dropout_rate': 0.5569166021521037, 'l2_reg_strength': 3.4579281743679756e-07}
# {'num_layers': 1, 'units_per_layer': 99, 'activation': 'relu', 'learning_rate': 0.008920124010267476, 'batch_size': 64, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.007470107366260217}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0007425464541967161, 'batch_size': 64, 'dropout_rate': 0.29048544296388107, 'l2_reg_strength': 0.007470107366260217}
# ...
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.00035637668950572665, 'batch_size': 16, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.001563589052639116}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00016119475783543539, 'batch_size': 32, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.001069738474626958, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.22568003567572126, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 64, 'dropout_rate': 0.5527734848372848, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 3, 'units_per_layer': 113, 'activation': 'relu', 'learning_rate': 0.2280089968383126, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.00018931360550548726, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0004943464383521633, 'batch_size': 32, 'dropout_rate': 0.11723404939760436, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.00035637668950572665, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 56, 'activation': 'tanh', 'learning_rate': 0.00035637668950572665, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.00014087499741278163}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 1, 'units_per_layer': 56, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.00014087499741278163}
# {'num_layers': 1, 'units_per_layer': 56, 'activation': 'relu', 'learning_rate': 0.054988073911687724, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.001069738474626958, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 97, 'activation': 'sigmoid', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 34, 'activation': 'tanh', 'learning_rate': 0.00010646729978131632, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 86, 'activation': 'tanh', 'learning_rate': 0.02574800854722326, 'batch_size': 32, 'dropout_rate': 0.22568003567572126, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 1, 'units_per_layer': 97, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.05817752114914293, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 113, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.11860009205520976, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.1455410620925624, 'l2_reg_strength': 9.292228052516331e-07}
# Generation 20/20
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 256, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00016119475783543539, 'batch_size': 32, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.686634843846195e-05}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'sigmoid', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 82, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.11723404939760436, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 64, 'dropout_rate': 0.0542829611526307, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 16, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'sigmoid', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 66, 'activation': 'relu', 'learning_rate': 0.00016119475783543539, 'batch_size': 32, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 6.67003506312095e-07}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.05817752114914293, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0007611232808732092, 'batch_size': 32, 'dropout_rate': 0.11723404939760436, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 97, 'activation': 'sigmoid', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.00035637668950572665, 'batch_size': 32, 'dropout_rate': 0.05817752114914293, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 128, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 8.490282199158554e-06}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 70, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.1455410620925624, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 66, 'activation': 'tanh', 'learning_rate': 0.0028882253510901664, 'batch_size': 32, 'dropout_rate': 0.11860009205520976, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 66, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.11860009205520976, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 26, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 2, 'units_per_layer': 111, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 0.0058062091901469465}
# {'num_layers': 1, 'units_per_layer': 113, 'activation': 'sigmoid', 'learning_rate': 0.054988073911687724, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.001069738474626958, 'batch_size': 32, 'dropout_rate': 0.22568003567572126, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.001069738474626958, 'batch_size': 32, 'dropout_rate': 0.22568003567572126, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 2, 'units_per_layer': 43, 'activation': 'tanh', 'learning_rate': 0.00035637668950572665, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 97, 'activation': 'relu', 'learning_rate': 0.009756376937941902, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'sigmoid', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 8.490282199158554e-06}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.08447407730666538, 'l2_reg_strength': 9.292228052516331e-07}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0007611232808732092, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.002245735688293682}
# {'num_layers': 1, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 0.001563589052639116}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.0647373656364273, 'l2_reg_strength': 0.0006293979219270594}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.054988073911687724, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 4.811374533609838e-06}
# {'num_layers': 4, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.00035637668950572665, 'batch_size': 32, 'dropout_rate': 0.05686471032592723, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 0.0002458822898557773}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 32, 'dropout_rate': 0.28917116004379856, 'l2_reg_strength': 0.0002501054980386268}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0021069688405578667, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0200806009466051e-05}
# {'num_layers': 2, 'units_per_layer': 97, 'activation': 'relu', 'learning_rate': 0.00037960250218771957, 'batch_size': 32, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.1964999377282025e-07}
# {'num_layers': 2, 'units_per_layer': 66, 'activation': 'tanh', 'learning_rate': 0.0028882253510901664, 'batch_size': 32, 'dropout_rate': 0.11860009205520976, 'l2_reg_strength': 1.2423716713631823e-06}
# {'num_layers': 3, 'units_per_layer': 126, 'activation': 'tanh', 'learning_rate': 0.007233563510649851, 'batch_size': 32, 'dropout_rate': 0.32902783314500206, 'l2_reg_strength': 1.1193058442345275e-05}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.0001311593247098535, 'batch_size': 16, 'dropout_rate': 0.42757355472801306, 'l2_reg_strength': 0.001563589052639116}
# {'num_layers': 2, 'units_per_layer': 126, 'activation': 'relu', 'learning_rate': 0.007233563510649851, 'batch_size': 64, 'dropout_rate': 0.15421699556008492, 'l2_reg_strength': 1.0257506616021155e-05}
